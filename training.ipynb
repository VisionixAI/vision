# %%
import cv2
import numpy as np
from ultralytics import YOLO

# --- CONFIG ---
NUM_ROWS, NUM_COLS = 3, 3  # Grid config
CAM_SOURCE = 1  # or your IP stream e.g. 'http://192.168.x.x:4747/video'

# --- Load YOLOv8-Segmentation Model ---    
model = YOLO("yolov8n-seg.pt")  # Replace with custom if trained on floor classes

# --- Utils ---
def draw_grid(image, mask, rows, cols):
    zones = []
    x, y, w, h = cv2.boundingRect(mask)
    cell_w, cell_h = w // cols, h // rows

    for i in range(rows):
        for j in range(cols):
            x1, y1 = x + j * cell_w, y + i * cell_h
            x2, y2 = x1 + cell_w, y1 + cell_h
            zones.append(((x1, y1), (x2, y2)))
            cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)

    return zones

# --- Main Loop ---
cap = cv2.VideoCapture(CAM_SOURCE)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]
    annotated = frame.copy()

    # --- Floor Mask Logic ---
    for i, seg in enumerate(results.masks.data if results.masks else []):
        mask = seg.cpu().numpy().astype(np.uint8) * 255
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        for cnt in contours:
            area = cv2.contourArea(cnt)
            if area > 10000:  # Only large masks
                cv2.drawContours(annotated, [cnt], -1, (0, 255, 0), 2)
                zones = draw_grid(annotated, cnt, NUM_ROWS, NUM_COLS)

    # --- Show Output ---
    cv2.imshow("VisionixAI Zone Detection", annotated)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 155.4ms
# Speed: 6.4ms preprocess, 155.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.4ms
# Speed: 1.9ms preprocess, 102.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.3ms
# Speed: 1.4ms preprocess, 91.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.2ms
# Speed: 1.1ms preprocess, 78.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.3ms
# Speed: 0.9ms preprocess, 77.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.1ms
# Speed: 1.0ms preprocess, 99.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.9ms
# Speed: 1.0ms preprocess, 83.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.9ms
# Speed: 1.3ms preprocess, 86.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.1ms
# Speed: 1.0ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.2ms
# Speed: 0.9ms preprocess, 78.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.9ms
# Speed: 1.1ms preprocess, 83.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.4ms
# Speed: 1.1ms preprocess, 78.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.2ms
# Speed: 1.4ms preprocess, 80.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.2ms
# Speed: 0.9ms preprocess, 76.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.1ms
# Speed: 1.2ms preprocess, 78.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.1ms
# Speed: 1.0ms preprocess, 83.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.7ms
# Speed: 1.1ms preprocess, 85.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.5ms
# Speed: 1.4ms preprocess, 78.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.5ms
# Speed: 1.2ms preprocess, 83.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.1ms
# Speed: 1.8ms preprocess, 84.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.4ms
# Speed: 1.4ms preprocess, 88.4ms inference, 24.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 book, 80.8ms
# Speed: 1.6ms preprocess, 80.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 book, 78.5ms
# Speed: 1.5ms preprocess, 78.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 78.5ms
# Speed: 1.1ms preprocess, 78.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 78.0ms
# Speed: 1.1ms preprocess, 78.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.6ms
# Speed: 1.3ms preprocess, 81.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.2ms
# Speed: 1.3ms preprocess, 77.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.5ms
# Speed: 2.0ms preprocess, 81.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.3ms
# Speed: 1.0ms preprocess, 78.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.8ms
# Speed: 1.2ms preprocess, 78.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 77.5ms
# Speed: 1.2ms preprocess, 77.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.1ms
# Speed: 1.5ms preprocess, 77.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.0ms
# Speed: 1.1ms preprocess, 76.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 book, 77.1ms
# Speed: 1.1ms preprocess, 77.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.5ms
# Speed: 1.0ms preprocess, 76.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 92.0ms
# Speed: 1.6ms preprocess, 92.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.8ms
# Speed: 1.4ms preprocess, 88.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.0ms
# Speed: 1.0ms preprocess, 80.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.7ms
# Speed: 1.1ms preprocess, 79.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.4ms
# Speed: 1.0ms preprocess, 79.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.8ms
# Speed: 1.1ms preprocess, 79.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.8ms
# Speed: 0.9ms preprocess, 78.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 82.7ms
# Speed: 1.0ms preprocess, 82.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.7ms
# Speed: 1.5ms preprocess, 78.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 1.0ms preprocess, 81.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.6ms
# Speed: 0.9ms preprocess, 76.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.1ms
# Speed: 1.0ms preprocess, 76.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 81.1ms
# Speed: 1.7ms preprocess, 81.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 77.0ms
# Speed: 1.0ms preprocess, 77.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.2ms
# Speed: 1.1ms preprocess, 77.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.9ms
# Speed: 1.2ms preprocess, 78.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.7ms
# Speed: 1.0ms preprocess, 74.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.9ms
# Speed: 1.0ms preprocess, 76.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.9ms
# Speed: 1.0ms preprocess, 75.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 90.4ms
# Speed: 1.3ms preprocess, 90.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 89.9ms
# Speed: 1.1ms preprocess, 89.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.4ms
# Speed: 1.1ms preprocess, 79.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.8ms
# Speed: 1.1ms preprocess, 75.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.7ms
# Speed: 0.9ms preprocess, 74.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 79.6ms
# Speed: 0.9ms preprocess, 79.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.9ms
# Speed: 1.0ms preprocess, 78.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.4ms
# Speed: 1.1ms preprocess, 78.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.9ms
# Speed: 1.1ms preprocess, 74.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.6ms
# Speed: 1.0ms preprocess, 80.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.4ms
# Speed: 1.1ms preprocess, 78.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 91.8ms
# Speed: 0.9ms preprocess, 91.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.1ms
# Speed: 1.0ms preprocess, 76.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.7ms
# Speed: 1.2ms preprocess, 75.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 77.8ms
# Speed: 1.1ms preprocess, 77.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.5ms
# Speed: 1.0ms preprocess, 75.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.5ms
# Speed: 0.9ms preprocess, 75.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.6ms
# Speed: 1.1ms preprocess, 75.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.4ms
# Speed: 1.0ms preprocess, 76.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.3ms
# Speed: 0.9ms preprocess, 76.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.0ms
# Speed: 1.0ms preprocess, 75.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.7ms
# Speed: 1.0ms preprocess, 74.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.5ms
# Speed: 1.0ms preprocess, 75.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.8ms
# Speed: 1.0ms preprocess, 73.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.1ms
# Speed: 1.2ms preprocess, 76.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 77.3ms
# Speed: 1.3ms preprocess, 77.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.6ms
# Speed: 0.9ms preprocess, 74.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.9ms
# Speed: 1.0ms preprocess, 76.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.1ms
# Speed: 1.2ms preprocess, 76.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.7ms
# Speed: 0.9ms preprocess, 75.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.8ms
# Speed: 1.0ms preprocess, 75.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.0ms
# Speed: 0.9ms preprocess, 75.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.9ms
# Speed: 1.4ms preprocess, 74.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.9ms
# Speed: 1.2ms preprocess, 77.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.4ms
# Speed: 0.9ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.9ms
# Speed: 1.3ms preprocess, 74.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.2ms
# Speed: 1.0ms preprocess, 76.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.1ms
# Speed: 1.1ms preprocess, 77.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.3ms
# Speed: 1.4ms preprocess, 75.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.3ms
# Speed: 1.2ms preprocess, 77.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 92.2ms
# Speed: 1.2ms preprocess, 92.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.9ms
# Speed: 1.0ms preprocess, 74.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.4ms
# Speed: 1.0ms preprocess, 75.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.0ms
# Speed: 1.2ms preprocess, 75.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 73.4ms
# Speed: 1.1ms preprocess, 73.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.4ms
# Speed: 1.0ms preprocess, 74.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.8ms
# Speed: 1.0ms preprocess, 78.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.1ms
# Speed: 1.0ms preprocess, 74.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.2ms
# Speed: 1.4ms preprocess, 76.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.9ms
# Speed: 0.9ms preprocess, 76.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.4ms
# Speed: 1.0ms preprocess, 74.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.0ms
# Speed: 0.9ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 81.0ms
# Speed: 1.0ms preprocess, 81.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.4ms
# Speed: 1.1ms preprocess, 76.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.2ms
# Speed: 1.0ms preprocess, 74.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.7ms
# Speed: 1.1ms preprocess, 76.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.0ms
# Speed: 0.9ms preprocess, 74.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 77.5ms
# Speed: 1.0ms preprocess, 77.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 80.0ms
# Speed: 1.1ms preprocess, 80.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 78.4ms
# Speed: 1.1ms preprocess, 78.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.7ms
# Speed: 1.1ms preprocess, 75.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 75.2ms
# Speed: 1.0ms preprocess, 75.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 72.6ms
# Speed: 1.0ms preprocess, 72.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.3ms
# Speed: 1.2ms preprocess, 74.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.9ms
# Speed: 1.0ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 72.6ms
# Speed: 1.1ms preprocess, 72.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.2ms
# Speed: 1.2ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.9ms
# Speed: 1.2ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 91.9ms
# Speed: 1.3ms preprocess, 91.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 74.7ms
# Speed: 1.4ms preprocess, 74.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 72.2ms
# Speed: 1.1ms preprocess, 72.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 76.3ms
# Speed: 1.3ms preprocess, 76.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.8ms
# Speed: 1.1ms preprocess, 72.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.4ms
# Speed: 1.5ms preprocess, 75.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.0ms
# Speed: 1.2ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.3ms
# Speed: 1.1ms preprocess, 73.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.3ms
# Speed: 1.3ms preprocess, 76.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 refrigerator, 73.2ms
# Speed: 1.3ms preprocess, 73.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.7ms
# Speed: 1.7ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.6ms
# Speed: 1.2ms preprocess, 74.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.2ms
# Speed: 1.0ms preprocess, 74.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.1ms
# Speed: 1.6ms preprocess, 74.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.4ms
# Speed: 1.3ms preprocess, 76.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.0ms
# Speed: 1.2ms preprocess, 77.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.5ms
# Speed: 1.0ms preprocess, 72.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 1 book, 74.7ms
# Speed: 1.2ms preprocess, 74.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.2ms
# Speed: 1.2ms preprocess, 73.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.2ms
# Speed: 1.1ms preprocess, 77.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.1ms
# Speed: 1.2ms preprocess, 74.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.6ms
# Speed: 1.2ms preprocess, 74.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 chairs, 2 dining tables, 73.4ms
# Speed: 1.1ms preprocess, 73.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 74.7ms
# Speed: 1.7ms preprocess, 74.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 chairs, 2 dining tables, 78.4ms
# Speed: 1.3ms preprocess, 78.4ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7 chairs, 2 dining tables, 76.7ms
# Speed: 1.3ms preprocess, 76.7ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 1 couch, 1 dining table, 96.3ms
# Speed: 1.5ms preprocess, 96.3ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 chairs, 2 dining tables, 78.7ms
# Speed: 1.5ms preprocess, 78.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 2 dining tables, 77.6ms
# Speed: 1.4ms preprocess, 77.6ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7 chairs, 1 couch, 2 dining tables, 77.3ms
# Speed: 1.7ms preprocess, 77.3ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 chairs, 1 couch, 2 dining tables, 78.1ms
# Speed: 1.4ms preprocess, 78.1ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8 chairs, 2 dining tables, 76.3ms
# Speed: 1.3ms preprocess, 76.3ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8 chairs, 2 dining tables, 75.1ms
# Speed: 1.3ms preprocess, 75.1ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 couch, 2 dining tables, 73.7ms
# Speed: 1.0ms preprocess, 73.7ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 9 chairs, 1 couch, 2 dining tables, 73.4ms
# Speed: 0.9ms preprocess, 73.4ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 8 chairs, 1 couch, 1 dining table, 74.1ms
# Speed: 1.1ms preprocess, 74.1ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 78.9ms
# Speed: 1.6ms preprocess, 78.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7 chairs, 1 couch, 1 dining table, 76.0ms
# Speed: 1.1ms preprocess, 76.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 74.1ms
# Speed: 1.2ms preprocess, 74.1ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 2 dining tables, 81.1ms
# Speed: 1.1ms preprocess, 81.1ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 82.0ms
# Speed: 1.4ms preprocess, 82.0ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 10 chairs, 1 couch, 1 dining table, 75.5ms
# Speed: 1.1ms preprocess, 75.5ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 dining table, 77.1ms
# Speed: 1.2ms preprocess, 77.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 78.2ms
# Speed: 1.1ms preprocess, 78.2ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 77.8ms
# Speed: 1.2ms preprocess, 77.8ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 77.5ms
# Speed: 1.2ms preprocess, 77.5ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 76.4ms
# Speed: 1.2ms preprocess, 76.4ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 74.3ms
# Speed: 1.1ms preprocess, 74.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 70.6ms
# Speed: 0.9ms preprocess, 70.6ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 1 dining table, 74.5ms
# Speed: 1.1ms preprocess, 74.5ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 10 chairs, 1 couch, 1 dining table, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 dining table, 73.9ms
# Speed: 1.1ms preprocess, 73.9ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12 chairs, 1 dining table, 71.8ms
# Speed: 1.1ms preprocess, 71.8ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 chairs, 1 couch, 1 dining table, 85.3ms
# Speed: 0.9ms preprocess, 85.3ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 1 dining table, 72.8ms
# Speed: 1.2ms preprocess, 72.8ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 chairs, 1 couch, 1 dining table, 76.5ms
# Speed: 1.1ms preprocess, 76.5ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 dining table, 76.1ms
# Speed: 1.3ms preprocess, 76.1ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 12 chairs, 1 dining table, 73.3ms
# Speed: 1.5ms preprocess, 73.3ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 12 chairs, 1 couch, 1 dining table, 75.4ms
# Speed: 1.4ms preprocess, 75.4ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 1 dining table, 74.0ms
# Speed: 1.3ms preprocess, 74.0ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 2 dining tables, 77.0ms
# Speed: 1.4ms preprocess, 77.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 chairs, 1 dining table, 76.3ms
# Speed: 1.1ms preprocess, 76.3ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 75.7ms
# Speed: 1.3ms preprocess, 75.7ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 77.5ms
# Speed: 1.1ms preprocess, 77.5ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 10 chairs, 1 couch, 1 dining table, 77.0ms
# Speed: 1.3ms preprocess, 77.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 77.8ms
# Speed: 1.3ms preprocess, 77.8ms inference, 11.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 78.7ms
# Speed: 1.2ms preprocess, 78.7ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 13 chairs, 1 dining table, 79.5ms
# Speed: 1.3ms preprocess, 79.5ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 dining table, 76.1ms
# Speed: 1.2ms preprocess, 76.1ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 chairs, 1 couch, 2 dining tables, 77.3ms
# Speed: 1.1ms preprocess, 77.3ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 chairs, 1 couch, 2 dining tables, 75.8ms
# Speed: 1.0ms preprocess, 75.8ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 74.8ms
# Speed: 1.4ms preprocess, 74.8ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 76.6ms
# Speed: 1.3ms preprocess, 76.6ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 73.9ms
# Speed: 0.9ms preprocess, 73.9ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 72.9ms
# Speed: 1.0ms preprocess, 72.9ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 9 chairs, 1 couch, 2 dining tables, 73.5ms
# Speed: 1.1ms preprocess, 73.5ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 1 dining table, 77.0ms
# Speed: 1.4ms preprocess, 77.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 2 dining tables, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11 chairs, 1 couch, 2 dining tables, 72.0ms
# Speed: 1.1ms preprocess, 72.0ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 2 dining tables, 72.8ms
# Speed: 0.9ms preprocess, 72.8ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 2 dining tables, 72.4ms
# Speed: 1.1ms preprocess, 72.4ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 12 chairs, 1 couch, 1 dining table, 76.4ms
# Speed: 1.0ms preprocess, 76.4ms inference, 10.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11 chairs, 1 couch, 1 dining table, 75.2ms
# Speed: 1.4ms preprocess, 75.2ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11 chairs, 1 couch, 1 dining table, 74.1ms
# Speed: 1.1ms preprocess, 74.1ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13 chairs, 1 dining table, 76.5ms
# Speed: 1.3ms preprocess, 76.5ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 76.3ms
# Speed: 1.3ms preprocess, 76.3ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 1 couch, 1 dining table, 76.8ms
# Speed: 0.9ms preprocess, 76.8ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 chairs, 1 couch, 1 dining table, 74.3ms
# Speed: 1.6ms preprocess, 74.3ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 76.6ms
# Speed: 1.3ms preprocess, 76.6ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 chairs, 1 dining table, 75.2ms
# Speed: 1.5ms preprocess, 75.2ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 chairs, 1 dining table, 73.1ms
# Speed: 1.3ms preprocess, 73.1ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 8 chairs, 2 couchs, 1 dining table, 71.4ms
# Speed: 0.9ms preprocess, 71.4ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11 chairs, 1 couch, 1 dining table, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11 chairs, 1 couch, 1 dining table, 75.7ms
# Speed: 1.4ms preprocess, 75.7ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12 chairs, 1 couch, 1 dining table, 77.3ms
# Speed: 1.2ms preprocess, 77.3ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12 chairs, 1 couch, 2 dining tables, 74.1ms
# Speed: 1.0ms preprocess, 74.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14 chairs, 1 couch, 1 dining table, 73.4ms
# Speed: 1.0ms preprocess, 73.4ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13 chairs, 1 couch, 1 dining table, 79.1ms
# Speed: 1.1ms preprocess, 79.1ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 11 chairs, 1 couch, 1 dining table, 80.1ms
# Speed: 1.7ms preprocess, 80.1ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 10 chairs, 1 couch, 1 dining table, 77.4ms
# Speed: 1.9ms preprocess, 77.4ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 76.9ms
# Speed: 1.4ms preprocess, 76.9ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 couch, 1 dining table, 95.1ms
# Speed: 1.1ms preprocess, 95.1ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 chairs, 1 dining table, 74.6ms
# Speed: 1.0ms preprocess, 74.6ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 7 chairs, 1 dining table, 76.1ms
# Speed: 1.6ms preprocess, 76.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 chairs, 73.1ms
# Speed: 0.9ms preprocess, 73.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 chairs, 75.2ms
# Speed: 1.0ms preprocess, 75.2ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 1 dining table, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 chairs, 74.3ms
# Speed: 1.1ms preprocess, 74.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 chairs, 73.2ms
# Speed: 0.9ms preprocess, 73.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 umbrella, 3 chairs, 74.1ms
# Speed: 1.0ms preprocess, 74.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 3 chairs, 73.6ms
# Speed: 1.0ms preprocess, 73.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 dining table, 73.5ms
# Speed: 1.0ms preprocess, 73.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 dining table, 74.4ms
# Speed: 1.3ms preprocess, 74.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 dining table, 72.5ms
# Speed: 0.9ms preprocess, 72.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 76.7ms
# Speed: 1.0ms preprocess, 76.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 umbrella, 74.6ms
# Speed: 1.0ms preprocess, 74.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 74.2ms
# Speed: 1.0ms preprocess, 74.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 73.8ms
# Speed: 1.1ms preprocess, 73.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 73.3ms
# Speed: 1.0ms preprocess, 73.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.3ms
# Speed: 1.1ms preprocess, 73.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.0ms
# Speed: 1.2ms preprocess, 77.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 74.0ms
# Speed: 0.9ms preprocess, 74.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.1ms
# Speed: 1.0ms preprocess, 74.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 73.9ms
# Speed: 0.9ms preprocess, 73.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 74.4ms
# Speed: 1.0ms preprocess, 74.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 89.0ms
# Speed: 1.7ms preprocess, 89.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 73.2ms
# Speed: 1.0ms preprocess, 73.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 75.4ms
# Speed: 1.1ms preprocess, 75.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 73.5ms
# Speed: 1.1ms preprocess, 73.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 dining table, 72.0ms
# Speed: 1.1ms preprocess, 72.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 73.3ms
# Speed: 1.0ms preprocess, 73.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 74.4ms
# Speed: 1.2ms preprocess, 74.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 75.1ms
# Speed: 1.1ms preprocess, 75.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 73.4ms
# Speed: 0.9ms preprocess, 73.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 73.6ms
# Speed: 1.0ms preprocess, 73.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 73.5ms
# Speed: 1.2ms preprocess, 73.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 71.8ms
# Speed: 1.1ms preprocess, 71.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 1 dining table, 73.9ms
# Speed: 1.1ms preprocess, 73.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 74.4ms
# Speed: 1.1ms preprocess, 74.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 72.9ms
# Speed: 1.0ms preprocess, 72.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 73.3ms
# Speed: 1.0ms preprocess, 73.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 73.3ms
# Speed: 1.7ms preprocess, 73.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7 chairs, 76.9ms
# Speed: 1.0ms preprocess, 76.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 71.9ms
# Speed: 1.0ms preprocess, 71.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 71.2ms
# Speed: 0.9ms preprocess, 71.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 72.6ms
# Speed: 1.0ms preprocess, 72.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 74.4ms
# Speed: 1.1ms preprocess, 74.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 7 chairs, 72.6ms
# Speed: 1.1ms preprocess, 72.6ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 chairs, 76.3ms
# Speed: 1.3ms preprocess, 76.3ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 6 chairs, 1 dining table, 75.8ms
# Speed: 1.0ms preprocess, 75.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 6 chairs, 1 dining table, 77.0ms
# Speed: 1.2ms preprocess, 77.0ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 chairs, 74.7ms
# Speed: 0.8ms preprocess, 74.7ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 74.1ms
# Speed: 1.1ms preprocess, 74.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 73.6ms
# Speed: 1.2ms preprocess, 73.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 72.2ms
# Speed: 1.1ms preprocess, 72.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 78.4ms
# Speed: 1.1ms preprocess, 78.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 74.5ms
# Speed: 1.0ms preprocess, 74.5ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 73.5ms
# Speed: 1.1ms preprocess, 73.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 73.9ms
# Speed: 1.0ms preprocess, 73.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 75.1ms
# Speed: 1.0ms preprocess, 75.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 75.5ms
# Speed: 1.0ms preprocess, 75.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 4 chairs, 1 dining table, 72.9ms
# Speed: 1.0ms preprocess, 72.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 1 dining table, 74.1ms
# Speed: 1.1ms preprocess, 74.1ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 1 dining table, 72.3ms
# Speed: 1.0ms preprocess, 72.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 1 dining table, 72.2ms
# Speed: 1.2ms preprocess, 72.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 74.3ms
# Speed: 1.5ms preprocess, 74.3ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 chairs, 93.9ms
# Speed: 1.3ms preprocess, 93.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 76.3ms
# Speed: 0.9ms preprocess, 76.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 74.1ms
# Speed: 0.9ms preprocess, 74.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 chairs, 74.3ms
# Speed: 1.5ms preprocess, 74.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 77.0ms
# Speed: 1.4ms preprocess, 77.0ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 6 chairs, 75.0ms
# Speed: 1.9ms preprocess, 75.0ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 5 chairs, 73.6ms
# Speed: 0.9ms preprocess, 73.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 5 chairs, 1 dining table, 76.1ms
# Speed: 1.0ms preprocess, 76.1ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 78.3ms
# Speed: 1.3ms preprocess, 78.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 77.1ms
# Speed: 1.0ms preprocess, 77.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 1 dining table, 73.2ms
# Speed: 1.0ms preprocess, 73.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 dining table, 76.8ms
# Speed: 1.6ms preprocess, 76.8ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 1 dining table, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 78.2ms
# Speed: 1.2ms preprocess, 78.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 chairs, 75.2ms
# Speed: 1.0ms preprocess, 75.2ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 74.3ms
# Speed: 1.3ms preprocess, 74.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 dining table, 73.7ms
# Speed: 1.1ms preprocess, 73.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 6 chairs, 74.6ms
# Speed: 1.1ms preprocess, 74.6ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 73.1ms
# Speed: 0.9ms preprocess, 73.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 74.4ms
# Speed: 1.1ms preprocess, 74.4ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 90.1ms
# Speed: 1.1ms preprocess, 90.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 1 dining table, 74.7ms
# Speed: 1.1ms preprocess, 74.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 chairs, 2 dining tables, 75.4ms
# Speed: 0.9ms preprocess, 75.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 74.1ms
# Speed: 1.2ms preprocess, 74.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 dining table, 76.1ms
# Speed: 1.1ms preprocess, 76.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 75.1ms
# Speed: 1.0ms preprocess, 75.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 3 chairs, 73.9ms
# Speed: 1.9ms preprocess, 73.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 4 chairs, 73.8ms
# Speed: 1.1ms preprocess, 73.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 1 dining table, 81.1ms
# Speed: 1.2ms preprocess, 81.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 chairs, 1 dining table, 80.3ms
# Speed: 1.0ms preprocess, 80.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 umbrella, 5 chairs, 1 dining table, 78.1ms
# Speed: 1.1ms preprocess, 78.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 dining table, 79.1ms
# Speed: 0.9ms preprocess, 79.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 1 dining table, 74.6ms
# Speed: 1.3ms preprocess, 74.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 1 dining table, 75.1ms
# Speed: 1.0ms preprocess, 75.1ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 dining table, 74.6ms
# Speed: 1.0ms preprocess, 74.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 dining table, 73.7ms
# Speed: 0.9ms preprocess, 73.7ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 chairs, 1 dining table, 73.2ms
# Speed: 1.6ms preprocess, 73.2ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 chairs, 1 dining table, 76.0ms
# Speed: 1.1ms preprocess, 76.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Install dependencies (run in your terminal first)
# pip install transformers torchvision opencv-python

from transformers import SegformerFeatureExtractor, SegformerForSemanticSegmentation
import torch
import cv2
from PIL import Image
import numpy as np

# Load the SegFormer model & extractor (ADE20K pretrained)
extractor = SegformerFeatureExtractor.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
model = SegformerForSemanticSegmentation.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")

# Load a test frame from your webcam
cap = cv2.VideoCapture(1)  # Or your IP cam

while True:
    ret, frame = cap.read()
    if not ret:
        break

    img_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    inputs = extractor(images=img_pil, return_tensors="pt")
    outputs = model(**inputs)
    seg = outputs.logits.argmax(dim=1).squeeze().numpy()

    # ADE20K class 3 is usually "floor" (you can change this based on output)
    floor_mask = (seg == 3).astype(np.uint8) * 255
    floor_mask_colored = cv2.merge([floor_mask, np.zeros_like(floor_mask), np.zeros_like(floor_mask)])

    # Resize mask to match frame size
    floor_mask_colored_resized = cv2.resize(floor_mask_colored, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)

    overlay = cv2.addWeighted(frame, 0.7, floor_mask_colored_resized, 0.3, 0)

    cv2.imshow("SegFormer Floor Detection", overlay)

    if cv2.waitKey(1) == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from transformers import SegformerFeatureExtractor, SegformerForSemanticSegmentation
from PIL import Image
import torch

# 1. Load segmentation model
# This model is pre-trained on the ADE20K dataset, which includes a 'floor' class (typically class ID 3).
extractor = SegformerFeatureExtractor.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
model = SegformerForSemanticSegmentation.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
model.eval() # Set the model to evaluation mode (disables dropout, etc.)

# 2. Set up video capture
# cap = cv2.VideoCapture(0) # Use 0 for the default webcam
cap = cv2.VideoCapture(1) # Use 1 for an external webcam, if available

if not cap.isOpened():
    print("Error: Could not open video stream. Check camera index or connection.")
    exit()

def divide_floor_into_zones(floor_mask, num_zones=5):
    """
    Divide the largest detected floor area into horizontal zones.

    Args:
        floor_mask (np.array): A binary mask (255 for floor, 0 for non-floor).
        num_zones (int): The number of horizontal zones to divide the floor into.

    Returns:
        list: A list of tuples, where each tuple contains (top_left, bottom_right)
              coordinates for a zone. Returns an empty list if no floor is detected.
    """
    zones = []
    # Find contours of the detected floor area
    contours, _ = cv2.findContours(floor_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # Find the largest contour, assuming it's the main floor
        largest_contour = max(contours, key=cv2.contourArea)
        
        # Get the bounding rectangle for the largest floor contour
        x, y, w, h = cv2.boundingRect(largest_contour)
        
        # Ensure the height is sufficient for division
        if h < num_zones: # Prevent division by zero or overly thin zones
            return []

        # Calculate the height of each horizontal zone
        zone_height = h // num_zones

        for i in range(num_zones):
            # Calculate top-left and bottom-right corners for each zone
            top_left = (x, y + i * zone_height)
            bottom_right = (x + w, y + (i + 1) * zone_height)
            
            # Ensure the last zone extends to the full height of the bounding box
            if i == num_zones - 1:
                bottom_right = (x + w, y + h)

            zones.append((top_left, bottom_right))
    return zones

## Main Loop for Video Processing ##
while True:
    ret, frame = cap.read() # Read a frame from the camera
    if not ret:
        print("Failed to grab frame, exiting...")
        break

    # Convert the OpenCV BGR frame to PIL RGB image for the model
    img_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    
    # Preprocess the image for the SegFormer model
    inputs = extractor(images=img_pil, return_tensors="pt")
    
    # Perform inference without tracking gradients
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Get the semantic segmentation map (class ID for each pixel)
    # The output logits are resized to the original input image size
    seg = outputs.logits.argmax(dim=1).squeeze().numpy()
    
    # Create a binary mask for the 'floor' class
    # ADE20K dataset: class ID 3 typically corresponds to 'floor'
    floor_mask = (seg == 3).astype(np.uint8) * 255 
    
    # Resize the floor mask back to the original frame dimensions for drawing
    floor_mask_resized = cv2.resize(floor_mask, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)

    # Divide the detected floor into zones
    zones = divide_floor_into_zones(floor_mask_resized, num_zones=5)

    # Create an overlay to draw zones
    overlay = frame.copy()
    
    # Draw each zone on the overlay
    for idx, (tl, br) in enumerate(zones):
        # Draw a green rectangle for the zone
        cv2.rectangle(overlay, tl, br, (0, 255, 0), 2) # Green color, 2 pixels thick
        
        # Put a label for the zone
        label_pos = (tl[0] + 10, tl[1] + 30)
        cv2.putText(overlay, f"Zone {idx+1}", label_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    # Blend the original frame with the overlay to show zones
    combined = cv2.addWeighted(frame, 0.7, overlay, 0.3, 0) # 70% original, 30% overlay

    # Display the result
    cv2.imshow("Floor Zones Detection", combined)

    # Break the loop if 'ESC' key is pressed
    if cv2.waitKey(1) == 27: 
        break

# Release the video capture object and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from transformers import SegformerFeatureExtractor, SegformerForSemanticSegmentation
from PIL import Image
import torch

# Load segmentation model
extractor = SegformerFeatureExtractor.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
model = SegformerForSemanticSegmentation.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
model.eval()

# Set video capture
cap = cv2.VideoCapture(1)

def divide_floor_into_zones(floor_mask, num_zones=5):
    """Divide floor area into horizontal zones inside the floor contour."""
    zones = []
    contours, _ = cv2.findContours(floor_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        x, y, w, h = cv2.boundingRect(largest_contour)
        zone_height = h // num_zones
        for i in range(num_zones):
            top_left = (x, y + i * zone_height)
            bottom_right = (x + w, y + (i + 1) * zone_height)
            zones.append((top_left, bottom_right))
    return zones

while True:
    ret, frame = cap.read()
    if not ret:
        break

    img_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    inputs = extractor(images=img_pil, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    
    seg = outputs.logits.argmax(dim=1).squeeze().numpy()
    floor_mask = (seg == 3).astype(np.uint8) * 255  # Class 3 = floor
    floor_mask_resized = cv2.resize(floor_mask, (frame.shape[1], frame.shape[0]), interpolation=cv2.INTER_NEAREST)

    zones = divide_floor_into_zones(floor_mask_resized)

    overlay = frame.copy()
    for idx, (tl, br) in enumerate(zones):
        cv2.rectangle(overlay, tl, br, (0, 255, 0), 2)
        label_pos = (tl[0] + 10, tl[1] + 30)
        cv2.putText(overlay, f"Zone {idx+1}", label_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    combined = cv2.addWeighted(frame, 0.7, overlay, 0.3, 0)
    cv2.imshow("Floor Zones", combined)

    if cv2.waitKey(1) == 27:  # ESC to break
        break

cap.release()
cv2.destroyAllWindows()
